# %%
# %pylab inline
import time
import ete3
from Bio import Phylo
from io import StringIO
from matplotlib import cm
from importlib import reload
import epistasis_methods as em
from scipy.optimize import curve_fit
import tree_methods
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Random Epistatic Landscapes With Diversity
# At each time step we pick one active leaf and find the next $\mu$ and thereby the $s$ characterizing a step from this branch.

# %%
def D_func(x):
    return abs(x)**.5

# %%
import epistasis_methods as em

reload(em)

N = 50
RE = em.RandomEvo(N,D_func,seed=1)
RE.run_evo()

# %%
plot(RE.mean_s_traj)
ylabel('mean fitness')
# Out:
# Text(0, 0.5, 'mean fitness')

# %%
figure(figsize=(12,4))
subplot(1,2,1)
plot(RE.num_active_traj)
ylabel('number of active nodes')
xlabel('steps taken')

subplot(1,2,2)
imshow(RE.cov_mat)

# %% [markdown]
# # Plotting with Bio Phylo

# %%
viridis = cm.get_cmap('viridis', 256)
color_dict = {}
for i,x in enumerate(RE.tree.nodes):
    color_dict[x] = viridis(i/N)

# %%
tree_string = RE.tree.get_full_newick()
handle = StringIO(tree_string)
T = Phylo.read(handle,'newick')
T.ladderize()

# %%
Phylo.draw(T,label_func=lambda x:None,branch_labels=lambda x:None,label_colors=color_dict)

# %% [markdown]
# # Plotting with ETE3

# %%
tree_string = RE.tree.get_full_newick()
T = ete3.Tree(tree_string,format=1)
color_dict = {}
for i,x in enumerate(RE.tree.nodes):
    color_dict[str(x)] = i/N

# %%
TS = ete3.TreeStyle()
TS.scale=4
TS.branch_vertical_margin=4
TS.show_leaf_name=False

# %%
rbow=cm.get_cmap('rainbow')

for n in T.traverse():
    nstyle=ete3.NodeStyle()
    nstyle["size"]=1
    if n.name!='root':
        nstyle["hz_line_color"]=matplotlib.colors.to_hex(rbow(color_dict[n.name]))
        nstyle["vt_line_color"]=matplotlib.colors.to_hex(rbow(color_dict[n.name]))
    nstyle["hz_line_width"]=3
    nstyle["vt_line_width"]=3
    n.set_style(nstyle)
# phylo.convert_to_ultrametric()
T.ladderize()
T.render('epistasis.pdf',tree_style=TS);

# %% [markdown]
# # Approximating power by sum of exponentials

# %%
def sum_exp(x,*params):
    L = len(params)
    assert L%2==0
    coeffs = params[:L//2]
    lens = params[L//2:]
    return sum([coeffs[i]*(1-exp(-x/l)) for i,l in enumerate(lens)],axis=0)

# %%
xtest = linspace(0,60,1000)

xfit = linspace(0,60,1000)
alpha = 0.5
y = xfit**alpha

popt,_ = curve_fit(sum_exp,xfit,y,p0=ones(2*3))

figure(figsize=[10,3])
subplot(1,2,1)
plot(xtest,xtest**alpha)
plot(xtest,sum_exp(xtest,*popt))
subplot(1,2,2)
plot(xtest,xtest**alpha-sum_exp(xtest,*popt))

# %%
# parameters for alpha = 0.5
pstar = popt

def D_func1(x):
    return abs(x)**.5

def D_func2(x):
    return sum_exp(abs(x),*pstar)

# %%
reload(em)

N = 100
RE1 = em.RandomEvo(N,D_func1,seed=1)
RE1.run_evo()

RE2 = em.RandomEvo(N,D_func2,seed=1)
RE2.run_evo()

# %%
figure(figsize=[10,3])
subplot(1,2,1)
plot(RE1.mean_s_traj,label='power law')
plot(RE2.mean_s_traj,label='sum of exponentials')

ylabel('mean fitness')
legend()

subplot(1,2,2)
plot(RE1.num_active_traj,label='power law')
plot(RE2.num_active_traj,label='sum of exponentials')

ylabel('number of active nodes')
xlabel('steps taken')
legend()

# %% [markdown]
# ## Only condition on parent

# %%
xfit = linspace(0,600,1000)
alpha = 0.5
y = xfit**alpha
popt,_ = curve_fit(sum_exp,xfit,y,p0=ones(2*3))

L = len(popt)
coeff_list = popt[:L//2]
corr_len_list = popt[L//2:]

# %%
reload(tree_methods)
reload(em)
RE = em.RandomEvo_Exp(coeff_list,corr_len_list,seed=10)
RE.run_evo(1000)

# %%
tree_string = RE.get_full_newick(mutations=False)
handle = StringIO(tree_string)
T = Phylo.read(handle,'newick')
T.ladderize()

Phylo.draw(T,label_func=lambda x:None,branch_labels=lambda x:None,label_colors=color_dict)

# %%
tree_string = RE.get_final_newick(mutations=False)
handle = StringIO(tree_string)
T = Phylo.read(handle,'newick')
T.ladderize()

Phylo.draw(T,label_func=lambda x:None,branch_labels=lambda x:None,label_colors=color_dict)

# %%
plot(RE.ds_traj)
plot(RE.mu_traj)
